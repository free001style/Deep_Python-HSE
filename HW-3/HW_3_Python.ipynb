# %% [markdown]
# # Домашнее задание 3
#
# **Выполнил:** <ФИО>
#
# **На сколько выполнил:** <Укажите, на сколько баллов по вашему мнению вы сделали>

# %% [markdown]
# **Правила игры:**
#
# * возле каждой задачи указано число баллов (в сококупности можно получить 10 баллов)
#
# * хотим чистый, читабельный код, сайты - с user-friendly интерфейсом)
#
# * к каждому заданию должен быть приложен код проекта, выложенный на Github (если вы пользуетесь ScraperAPI или другими ключами, то ключи необходимо убирать)
#
# * Оценивание будет происзодить в первую очередь по функциональности - все ли работает и работает так, как должно (но за полное отсутствие стиля мы будем снижать)
#
# P.S. В данном задании вам не потребуется ScraperAPI :з
#
# **Любые extra-вещи будут оцениваться в плюс как доп баллы**

# %% [markdown]
# ## Задание 1 (3 балла)

# %% [markdown]
# Парсим [Steam](https://store.steampowered.com/) с помощью Scrapy!
#
# Необходимо выбрать 3 запроса (например, "инди", "стратегии", "minecraft", на каждый запрос должно быть минимум 90 результатов), и вытащить по ним:
#
# * Все игры на первых 2 страницах (найдите, каким образом отображаются страницы)
#
# И для каждой игры вытащить:
#
# * Название
#
# * Категорию (весь путь, за исключением Все игры и самого названия игры)
#
# * Число всех обзоров и общая оценка
#
# * Дата выхода
#
# * Разработчик
#
# * Метки (тэги) игры
#
# * Цена
#
# * Доступные платформы
#
# Сохраните игры в формате json, оставив только игры, выпущенные после 2000 года
#
# Чтобы было проще, в репозитории с ДЗ выложены скрины, где можно посмотреть, где и какие поля находятся

# %% [markdown]
# Всё лежит в отдельном файле

# %% [markdown]
# ## Задание 2 (4 балла)

# %% [markdown]
# Создайте сайт с помощью Flask или Django. Будем делать конструктор резюме!
#
# Общая структура сайта:
#
# 1. Страничка с авторизацией и регистрацией
#
# 2. После авторизации, должна быть страница с формой, в которой необходимо заполнить форму (если пользователь уже заполнял форму, то в формы уже должен быть подгружен текст, который был заполнен, для этого должна быть отдельная кнопочка для сохранения в черновик)
#
# 3. Страница со скоинструированным резюме, который может быть превращен в PDF и выгружен (для этого можно использовать [pdfkit](https://pypi.org/project/pdfkit/))
#
# На всякий случай: пользователь не может посмотреть чужие резюме

# %% [markdown]
# Немного не хватило времени, поэтому сделал слегка тупую фигню.
# Залил сайт на докер хаб, вот [сюда](https://hub.docker.com/r/free001style/flaskapp/)
# Потом я пошёл на яндекс клауд, что создать виртуальную машину. Но начались какие-то приколы: когда я создавал аккаунт для это машины со статусом editor, мне просто не давали создать её(писали, что у меня нет прав). Тогда я решил, что можно создать другой акк и попробовать с него, но его тут же кинули в бан, как и второй и третий. Потом я решил, что пора включать ВПН, но, почему-то, это тоже не помогло(возможно они запомнили мою карту, хотя я её использовал всего два раза). Далее я нашёл человека, которому показал, куда тыкать и он всё сделал. Ура, у меня есть айпишник и ВМ. Я туда захожу, ставлю докер и пулю образ. Запускаю и ничего не работает. Пишет, что образ был сделан под платформу linux/arm64/v8, но ВМ умеет работать лишь с linux/arm64. Покопавшись в интернетах нашёл, что это приколы моего любимого М1(честно любимого) и надо руками было прописать, что образ нужен для платфомр linux/arm64. Удалил образ, заново его залил на докер хаб; начинаю пулить его на ВМ, и тут выскакивает сообщение, что у меня не хватает памяти, что в целом не удивительно, ведь у меня всего 2 ГБ. Сношу старый образ вместе с его контейнерами, заново пулю, вроде всё хорошо. Запускаю образ, он открывается на локальном сервере и всё хорошо. Но это не то, чего от нас хотят. Тогда я прошу докер, что он это открыл на том адресе, который дал мне яндекс. И...
# Ничего не работает.

# %% [markdown]
# ![Screenshot 2022-12-07 at 20.55.18.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-12-07 at 20.55.26.png](data:image/png;base64,...)

# %% [markdown]
# ![2022-12-07 20.56.51.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Задание 3* (2 балла)
#
# Добавьте возможность загрузить картинку в резюме (для исходного задания это не требуется)
#
# Разверните приложение на Yandex.Cloud или на любом другом хосте (если знаете куда можно)

# %% [markdown]
# ## Задание 4 (3 балла)

# %% [markdown]
# Отрисуйте с помощью Dash или StreamLit данные из данного [датасета](https://www.kaggle.com/datasets/michaelbryantds/crimedata)
#
# Здесь необходимо провести самостоятельный анализ данных (можно даже в ноутбуке), в качестве результата необходим дашборд, внутри которого будет:
#
# * Не менее 5 селекторов
#
# * Не менее 5 различных графиков, которые показывали бы зависимость между преступлениями (на ваш выбор, там можно выбрать) и выбранными вами показателями
#
# Дашборд должен быть стилистически оформлен

# %% [markdown]
# Найдя на кагле ссылку на похожий [датасет](https://archive.ics.uci.edu/ml/datasets/Communities+and+Crime) с описанием колонок, почитаем хотя бы что они значат, а то пока ничего непонятно.

# %% [markdown]
# Начнём с простого: люди могут идти на преступление по многим причина, но основная --- это финансовая выгода. Поэтому посмотрим на зарплаты в штатах и на процент бедных(по мнению американцев) людей.
#
# Что видим? Ну чем средняя зарплата в штате больше, чем меньший процент людей находится за чертой бедности(было бы странно, если бы было наоборот).

# %% [markdown]
# Теперь посмотрим на корреляцию процента иммигрантов, которые прибыли в страну разное количество лет назад, и их рас (ну и всё это по штатам).
#
# Что теперь видим? Чёрные едут в Вашингтон(вспоминаем штурм Капитолия), азиаты едут в Калифорнию(лететь походу долго не любят), испанцы поближе к Мексике, а белые ... Они всюду)

# %% [markdown]
# Теперь уже можно посмотреть на виды преступлений. К сожалению, описание есть только для одной колонки(ViolentCrimesPerPop). Ну некоторые и так понятны.
#
# Что видим? Округ Колумбия лидирует в 7 из 10 видов преступлений. Тут у меня есть два объяснения: во-первых, можно вспомнить прошлый пункт, откуда мы узнали, что чёрные едут именно туда(дальше понятно); но во-вторых, насколько известно, Округ Колумбия --- это формально только один Вашингтон, а в остальных штатах мы смотрим среднее по всем community штата.

# %% [markdown]
# Теперь хочется посмотреть на количество полицейских в каждом штате. Хочется посмотреть, потому что мне кажется, что чем больше полицейских, тем меньше преступлений. Хотя, возможно, наоборот: в штаты, где много преступлений, направляют больше полицейских(если честно, то совершенно не знаю, как это там работает, учитывая то, что каждый штат --- это почти как отдельное государство)
#
# Что видим? Да что-то не очень мои предположения совпадают с реальностью. Видно, что очень много относительно других штатов полицейских в Колумбии, но опять же, либо потому что это город, а не штат, либо из-за большого числа преступлений(о чём я писал ранее).

# %% [markdown]
# Ну и последний график был сделан больше по приколу. Хотелось посмотреть, насколько много людей живёт без телефонов и без водопровода, то есть в целом, бедно ли живут? Как видно, что процент отсутствия водопровода очень низкий, а вот телефонов не совсем. В нашем уже полюбившемся Нью-Мексико, например, телефонов нет у 12% населения. Хотя может и действительно, телефоны в домах --- это уже немного кринж?
